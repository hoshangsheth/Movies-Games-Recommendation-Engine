# %% [markdown]
# # Movies Recommendation Engine:
# ---
# ## Project Overview:
#  - This end-to-end Movie Recommendation System delivers personalized film suggestions by combining content-based filtering with a smart NLP-powered search using fuzzy string matching for enhanced user input handling.
#  - It leverages metadata from the TMDB API, processes over 9,000 movies, and extracts key features such as genres, descriptions, and popularity to compute similarity scores using TF-IDF vectorization and cosine similarity.
#  - The system is deployed with an intuitive Streamlit interface, enabling users to:
#    - Enter movie names (even approximate or partial)
#    - Receive relevant recommendations with posters, ratings, and direct streaming links
#
# The project demonstrates hands-on expertise in data preprocessing, natural language processing, similarity algorithms, and full-stack deployment, making it a strong addition to any Data Science portfolio.

# %% [markdown]
# ## 🎬 This notebook will build the Movie Recommendation Engine by:
# 🧹 Textual Data Cleaning & Preprocessing:
#   - Remove leading/trailing spaces, special characters, and lowercase the text for uniformity.
#   - Construct a custom textual feature called “soup” by combining metadata like title, description, genre, etc.
#   - Apply lemmatization to reduce words to their base form, improving matching performance.
#
# 🔍 Smart Search with Fuzzy Matching:
#   - Use fuzzywuzzy’s process.extractOne() to allow approximate string matching for user input.
#   - Supports partial titles, misspellings, or non-standard casing, making the search experience seamless.
#   - The closest matched title is passed to the hybrid recommendation engine for fetching results.
#
# 📊 TF-IDF Vectorization for Content-Based Filtering:
#   - Vectorize the “soup” using TF-IDF to capture semantic relevance among movies.
#   - Cosine similarity is computed on these vectors to identify textually similar movies.
#
# 🎯 Recommendation Output:
#   - For each search query, return the Top 10 recommended movies based on computed score.
#
# ---

# %%
# Import library:
import pandas as pd

# Load data:
movies = pd.read_csv("tmdb_movies.csv")

# Preview the data:
movies.head(10)       # First 10 rows
# Out:
#         id                             title language  \
# 0  1197306                     A Working Man       en
# 1  1471014               Van Gogh by Vincent       en
# 2   668489                             Havoc       en
# 3   950387                 A Minecraft Movie       en
# 4   986056                     Thunderbolts*       en
# 5  1225915     Jewel Thief: The Heist Begins       hi
# 6   324544                 In the Lost Lands       en
# 7   822119  Captain America: Brave New World       en
# 8  1153714                Death of a Unicorn       en
# 9  1180906                       Desert Dawn       en
#
#                                          description           genre_id  \
# 0  Levon Cade left behind a decorated military ca...         28, 80, 53
# 1  In a career that lasted only ten years, Vincen...                 99
# 2  When a drug heist swerves lethally out of cont...         28, 80, 53
# 3  Four misfits find themselves struggling with o...  10751, 35, 12, 14
# 4  After finding themselves ensnared in a death t...        28, 12, 878
# 5  In this high-octane battle of wits and wills, ...             28, 53
# 6  A queen sends the powerful and feared sorceres...         28, 14, 12
# 7  After meeting with newly elected U.S. Presiden...        28, 53, 878
# 8  A father and daughter accidentally hit and kil...     27, 14, 35, 12
# 9  A newly appointed small-town sheriff and his b...   28, 80, 9648, 53
#
#   release_date  rating                                        poster_path  \
# 0  26 Mar 2025   6.489  https://image.tmdb.org/t/p/original/6FRFIogh3z...
# 1  26 Mar 2025   6.375  https://image.tmdb.org/t/p/original/z73X4WKZgh...
# 2  24 Apr 2025   6.608  https://image.tmdb.org/t/p/original/r46leE6PSz...
# 3  31 Mar 2025   6.189  https://image.tmdb.org/t/p/original/iPPTGh2OXu...
# 4  30 Apr 2025   7.615  https://image.tmdb.org/t/p/original/vnfgoohSwK...
# 5  25 Apr 2025   6.793  https://image.tmdb.org/t/p/original/eujLbO0kf1...
# 6  27 Feb 2025   6.323  https://image.tmdb.org/t/p/original/dDlfjR7gll...
# 7  12 Feb 2025   6.160  https://image.tmdb.org/t/p/original/pzIddUEMWh...
# 8  27 Mar 2025   6.200  https://image.tmdb.org/t/p/original/lXR32JepFw...
# 9  15 May 2025   0.000  https://image.tmdb.org/t/p/original/S21BfLrJSD...
#
#                                genres  \
# 0             Action, Crime, Thriller
# 1                         Documentary
# 2             Action, Crime, Thriller
# 3  Family, Comedy, Adventure, Fantasy
# 4  Action, Adventure, Science Fiction
# 5                    Action, Thriller
# 6          Action, Fantasy, Adventure
# 7   Action, Thriller, Science Fiction
# 8  Horror, Fantasy, Comedy, Adventure
# 9    Action, Crime, Mystery, Thriller
#
#                                             top_cast  \
# 0  Jason Statham, Jason Flemyng, Merab Ninidze, M...
# 1  Zahra Ahmadi, Jack Etchells, Adam Woolley, Fra...
# 2  Tom Hardy, Jessie Mei Li, Timothy Olyphant, Fo...
# 3  Jason Momoa, Jack Black, Sebastian Eugene Hans...
# 4  Florence Pugh, Sebastian Stan, Julia Louis-Dre...
# 5  Saif Ali Khan, Jaideep Ahlawat, Nikita Dutta, ...
# 6  Milla Jovovich, Dave Bautista, Arly Jover, Ama...
# 7  Anthony Mackie, Harrison Ford, Danny Ramirez, ...
# 8  Jenna Ortega, Paul Rudd, Will Poulter, Richard...
# 9    Kellan Lutz, Cam Gigandet, Chad Michael Collins
#
#                                    cast_profile_path  \
# 0  https://image.tmdb.org/t/p/w200/whNwkEQYWLFJA8...
# 1  https://image.tmdb.org/t/p/w200/WlF6GWX98ilKoa...
# 2  https://image.tmdb.org/t/p/w200/d81K0RH8UX7tZj...
# 3  https://image.tmdb.org/t/p/w200/3troAR6QbSb6nU...
# 4  https://image.tmdb.org/t/p/w200/6Sjz9teWjrMY9l...
# 5  https://image.tmdb.org/t/p/w200/kzOy1DoCeLoKJ0...
# 6  https://image.tmdb.org/t/p/w200/usWnHCzbADijUL...
# 7  https://image.tmdb.org/t/p/w200/eZSIDrtTzhvaby...
# 8  https://image.tmdb.org/t/p/w200/7oUAtVgZU0uLdU...
# 9  https://image.tmdb.org/t/p/w200/pLzdFABlU6oS2B...
#
#                                             keywords  \
# 0  based on novel or book, kidnapping, vigilante,...
# 1                                              other
# 2  winter, detective, rescue mission, shootout, d...
# 3  friendship, surrealism, exploration, portal, m...
# 4  villain, based on comic, aftercreditsstinger, ...
# 5                                              other
# 6  witch, dystopia, sorcery, betrayal, based on s...
# 7  hero, superhero, revenge, aftercreditsstinger,...
# 8  dark comedy, unicorn, dark fantasy, horror com...
# 9                                              other
#
#                                           watch_link languages
# 0                        https://www.themoviedb.org/   English
# 1                        https://www.themoviedb.org/   English
# 2  https://www.themoviedb.org/movie/668489-havoc/...   English
# 3                        https://www.themoviedb.org/   English
# 4                        https://www.themoviedb.org/   English
# 5  https://www.themoviedb.org/movie/1225915/watch...     Hindi
# 6                        https://www.themoviedb.org/   English
# 7                        https://www.themoviedb.org/   English
# 8                        https://www.themoviedb.org/   English
# 9                        https://www.themoviedb.org/   English

# %%
# Data information:
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8245 entries, 0 to 8244
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8245 non-null   int64
#  1   title              8245 non-null   object
#  2   language           8245 non-null   object
#  3   description        8245 non-null   object
#  4   genre_id           8245 non-null   object
#  5   release_date       8245 non-null   object
#  6   rating             8245 non-null   float64
#  7   poster_path        8245 non-null   object
#  8   genres             8245 non-null   object
#  9   top_cast           8245 non-null   object
#  10  cast_profile_path  8245 non-null   object
#  11  keywords           8245 non-null   object
#  12  watch_link         8245 non-null   object
#  13  languages          8245 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 901.9+ KB

# %% [markdown]
# ## Cleaning Textual Data

# %%
# Starting with cleaning Title data into a Cleaned_Title:
# This Cleaned Title column will be used to match the user input's movie to provide recommendation

import unicodedata
import re

def clean_title(title):
    title = unicodedata.normalize('NFKD', title).encode('ascii', 'ignore').decode('utf-8', 'ignore')
    title = title.lower().strip()
    title = re.sub(r'[^a-z0-9\s]','',title)
    title = re.sub(r'\s+',' ', title)
    return title

# Apply the function to a newly created column of cleaned title:
movies['title_clean'] = movies['title'].apply(clean_title)

# Preview:
movies.head(5)
# Out:
#         id                title language  \
# 0  1197306        A Working Man       en
# 1  1471014  Van Gogh by Vincent       en
# 2   668489                Havoc       en
# 3   950387    A Minecraft Movie       en
# 4   986056        Thunderbolts*       en
#
#                                          description           genre_id  \
# 0  Levon Cade left behind a decorated military ca...         28, 80, 53
# 1  In a career that lasted only ten years, Vincen...                 99
# 2  When a drug heist swerves lethally out of cont...         28, 80, 53
# 3  Four misfits find themselves struggling with o...  10751, 35, 12, 14
# 4  After finding themselves ensnared in a death t...        28, 12, 878
#
#   release_date  rating                                        poster_path  \
# 0  26 Mar 2025   6.489  https://image.tmdb.org/t/p/original/6FRFIogh3z...
# 1  26 Mar 2025   6.375  https://image.tmdb.org/t/p/original/z73X4WKZgh...
# 2  24 Apr 2025   6.608  https://image.tmdb.org/t/p/original/r46leE6PSz...
# 3  31 Mar 2025   6.189  https://image.tmdb.org/t/p/original/iPPTGh2OXu...
# 4  30 Apr 2025   7.615  https://image.tmdb.org/t/p/original/vnfgoohSwK...
#
#                                genres  \
# 0             Action, Crime, Thriller
# 1                         Documentary
# 2             Action, Crime, Thriller
# 3  Family, Comedy, Adventure, Fantasy
# 4  Action, Adventure, Science Fiction
#
#                                             top_cast  \
# 0  Jason Statham, Jason Flemyng, Merab Ninidze, M...
# 1  Zahra Ahmadi, Jack Etchells, Adam Woolley, Fra...
# 2  Tom Hardy, Jessie Mei Li, Timothy Olyphant, Fo...
# 3  Jason Momoa, Jack Black, Sebastian Eugene Hans...
# 4  Florence Pugh, Sebastian Stan, Julia Louis-Dre...
#
#                                    cast_profile_path  \
# 0  https://image.tmdb.org/t/p/w200/whNwkEQYWLFJA8...
# 1  https://image.tmdb.org/t/p/w200/WlF6GWX98ilKoa...
# 2  https://image.tmdb.org/t/p/w200/d81K0RH8UX7tZj...
# 3  https://image.tmdb.org/t/p/w200/3troAR6QbSb6nU...
# 4  https://image.tmdb.org/t/p/w200/6Sjz9teWjrMY9l...
#
#                                             keywords  \
# 0  based on novel or book, kidnapping, vigilante,...
# 1                                              other
# 2  winter, detective, rescue mission, shootout, d...
# 3  friendship, surrealism, exploration, portal, m...
# 4  villain, based on comic, aftercreditsstinger, ...
#
#                                           watch_link languages  \
# 0                        https://www.themoviedb.org/   English
# 1                        https://www.themoviedb.org/   English
# 2  https://www.themoviedb.org/movie/668489-havoc/...   English
# 3                        https://www.themoviedb.org/   English
# 4                        https://www.themoviedb.org/   English
#
#            title_clean
# 0        a working man
# 1  van gogh by vincent
# 2                havoc
# 3    a minecraft movie
# 4         thunderbolts

# %%
# Create soup using Genres, Description and Language:
movies['soup'] = movies['genres'] + ' ' + movies['description'] + ' ' + movies['language'] + ' ' + movies['top_cast'] + ' ' + movies['keywords']
print(f'Generated Soup:\n{movies['soup'][0]}')
# Out:
# Generated Soup:
# Action, Crime, Thriller Levon Cade left behind a decorated military career in the black ops to live a simple life working construction. But when his boss's daughter, who is like family to him, is taken by human traffickers, his search to bring her home uncovers a world of corruption far greater than he ever could have imagined. en Jason Statham, Jason Flemyng, Merab Ninidze, Maximilian Osinski, Cokey Falkow based on novel or book, kidnapping, vigilante, missing person, black ops, construction worker, criminal conspiracy, absurd

# %%
# Check:
movies['top_cast'][0]
# Out:
# 'Jason Statham, Jason Flemyng, Merab Ninidze, Maximilian Osinski, Cokey Falkow'

# %%
# Clean and Lemmatize soup:

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Initialize StopWords and lemmatizer:
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Define the function to clean the soup:
def clean_text(text,is_cast=False):
    # If its cast data, just convert to lowercase and strip
    if is_cast:
        return ', '.join([actor.lower().strip() for actor in text.split(',')])
    
    # Otherwise, clean the text as usual
    tokens = nltk.word_tokenize(re.sub(r'\W',' ', text.lower()))
    filtered = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return ' '.join(filtered)

# Apply functon to soup
movies['cleaned_soup'] = movies['soup'].apply(lambda x: clean_text(x))
# Apply function to cast
movies['cleaned_top_cast'] = movies['top_cast'].apply(lambda x: clean_text(x, is_cast=True))

# %%
# Clean properly:
movies['cleaned_cast'] = movies['top_cast'].str.lower().str.strip().str.replace(', ', ' ')

# Convert into final soup:
movies['final_soup'] = movies['cleaned_soup'] + ' ' + movies['cleaned_cast']

# %%
# Preview finalized soup:
movies['final_soup'][2]
# Out:
# 'action crime thriller drug heist swerve lethally control jaded cop fight way corrupt city criminal underworld save politician son en tom hardy jessie mei li timothy olyphant forest whitaker justin cornwell winter detective rescue mission shootout dirty cop criminal underworld crooked politician estranged son aggressive insecure christmas grim drug deal night club brutal violence tom hardy jessie mei li timothy olyphant forest whitaker justin cornwell'

# %% [markdown]
# ## Preprocessesing Data:

# %%
# Apply TF-IDF Vectorization on Soup:

from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize the Vectorizer:
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(movies['final_soup'])

# Print output:
print(f"Successfully vectorized soup:\n{tfidf_matrix.shape}")
# Out:
# Successfully vectorized soup:
# (8245, 33228)

# %% [markdown]
# ## Computing Cosine Similarity using TFIDF Vectorized Data

# %%
# Import required library:
from sklearn.metrics.pairwise import cosine_similarity

# Compute:
cosine_sim = cosine_similarity(tfidf_matrix,tfidf_matrix)

# Print output:
print(f"Computation Complete: {cosine_sim.shape}")
# Out:
# Computation Complete: (8245, 8245)

# %%
# Save the cosine sim using NumPy:
import numpy as np
np.save('cosine_sim.npy',cosine_sim)
print("Saved!")
# Out:
# Saved!

# %%
# Save the data ready for recommendation engine:
movies.to_csv("movies_recommend.csv", index=False)
print("Saved!")
# Out:
# Saved!

# %% [markdown]
# # Content Based Recommendation Engine with smart search

# %%
# Saving movies_recommend.csv data as pkl file:
import pandas as pd
import pickle

# Load the CSV file:
movies_df = pd.read_csv("movies_recommend.csv")

# Save into pkl:
with open("movies_recommend.pkl", 'wb') as f:
    pickle.dump(movies_df, f)

print("Pickel file saved successfully.")
# Out:
# Pickel file saved successfully.

# %%
# Saving cosine similarity matrix as pkl file:

with open("cosine_sim.pkl", "wb") as f:
    pickle.dump(cosine_sim, f)

print("Precomputed Cosine sim is saved.")
# Out:
# Precomputed Cosine sim is saved.

# %%
import re
import pandas as pd
import numpy as np
# Load data:
movies = pd.read_csv("../Data/movies_recommended.csv")
# Load precomputed cosine sim:
cosine_sim = np.load("../Recommendation Engine/cosine_sim.npy")

# %%
# Save to pkl file:
import pickle
with open('movies_recommended.pkl', 'wb') as f:
    pickle.dump(movies, f)

print("Pickle file saved successfully")
# Out:
# Pickle file saved successfully

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8245 entries, 0 to 8244
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 8245 non-null   int64
#  1   title              8245 non-null   object
#  2   language           8245 non-null   object
#  3   description        8245 non-null   object
#  4   genre_id           8245 non-null   object
#  5   release_date       8245 non-null   object
#  6   rating             8245 non-null   float64
#  7   poster_path        8245 non-null   object
#  8   genres             8245 non-null   object
#  9   top_cast           8245 non-null   object
#  10  cast_profile_path  8245 non-null   object
#  11  keywords           8245 non-null   object
#  12  watch_link         8245 non-null   object
#  13  languages          8245 non-null   object
#  14  title_clean        8245 non-null   object
#  15  soup               8245 non-null   object
#  16  cleaned_soup       8245 non-null   object
#  17  cleaned_top_cast   8245 non-null   object
#  18  cleaned_cast       8245 non-null   object
#  19  final_soup         8245 non-null   object
#  20  video_name         8245 non-null   object
#  21  video_key          8245 non-null   object
#  22  site               8245 non-null   object
#  23  type               8245 non-null   object
#  24  size               8245 non-null   float64
#  25  official           8245 non-null   object
# dtypes: float64(2), int64(1), object(23)
# memory usage: 1.6+ MB

# %% [markdown]
# # === Content-based recommendation function ===
# ---

# %%
movie_aliases = {
    "znmd": "Zindagi Na Milegi Dobara",
    "dch": "Dil Chahta Hai",
    "3idiots": "3 Idiots",
    "k3g": "Kabhi Khushi Kabhie Gham",
    "lagaan": "Lagaan",
    "tzp": "Taare Zameen Par",
    "bb": "Bajrangi Bhaijaan",
    "dangal": "Dangal",
    "aaa": "Andaz Apna Apna",
    "barfi": "Barfi!",
    "mi": "Mission Impossible",
    "tdk": "The Dark Knight",
    "inception": "Inception",
    "lotr": "The Lord of the Rings",
    "matrix": "The Matrix",
    "endgame": "Avengers: Endgame",
    "forrest": "Forrest Gump",
    "interstellar": "Interstellar",
    "jp": "Jurassic Park",
    "potc": "Pirates of the Caribbean"
}

# %%
from rapidfuzz import process, fuzz

def recommend_movies(user_input, top_n=10):
    try:
        # Validate user input
        if not isinstance(user_input, str) or not user_input.lower().strip():
            raise ValueError("User input must not be empty. Please add a movie to get recommendations.")
        
        # Clean user input
        user_input_clean = re.sub(r'[^a-zA-Z0-9\s]', '', user_input.lower().strip())

        # Use alias if available
        if user_input_clean in movie_aliases:
            user_input_clean = movie_aliases[user_input_clean]

        # Handle case where no fuzzy match is found
        match_result = process.extractOne(user_input_clean, movies['title_clean'].to_list(), scorer=fuzz.ratio)
        if match_result is None:
            raise ValueError(f"Movie {user_input} is not updated in the data. It will be added in future update of application.")
        
        best_match = match_result[0]
        print(f"Best Match is: {best_match}")

        # Get index of the best match
        idx = movies[movies['title_clean'] == best_match].index[0]

        # Ensure that idx is valid
        if idx < 0 or idx >= len(movies):
            raise IndexError(f"Index {idx} is out of range.")
        
        # Calculate similarity scores directly from the precomputed cosine_sim matrix
        sim_scores = list(enumerate(cosine_sim[idx]))      # Use the precomputed cosine similarity matrix

        # Sort the similarity scores (excluding the movie itself)
        similar_movies_idx = sorted(sim_scores, key=lambda x: x[1], reverse=True)[1:top_n+1]

        # Prepare results
        results = []
        for i, _ in similar_movies_idx:
            movie_data = movies.loc[i]

            # Check if all necessary fields exist
            if any(field not in movie_data for field in ['title', 'top_cast','cast_profile_path', 'description', 'genres', 'languages', 'rating', 'poster_path', 'release_date', 'watch_link']):
                continue

            # Get trailer info if available:
            video_key = movie_data.get('video_key')
            trailer_url = f"https://www.youtube.com/watch?v={video_key}" if pd.notna(video_key) else None

            results.append({
                'Title': movies.loc[i,'title'],
                'Top Cast': movies.loc[i, 'top_cast'],
                'Cast Picture': movies.loc[i, 'cast_profile_path'],
                'Description': movies.loc[i,'description'],
                'Genre': movies.loc[i,'genres'],
                'Language': movies.loc[i,'languages'],
                'Release Date': movies.loc[i, 'release_date'],
                'Rating': movies.loc[i,'rating'],
                'Poster': movies.loc[i,'poster_path'],
                'Stream': movies.loc[i, 'watch_link'],
                'Trailer': trailer_url
            })


        return results
    
    except ValueError as ve:
        return {'Error': str(ve)}
    
    except IndexError as ie:
        return {'Error': f'Index error: {str(ie)}'}
    
    except Exception as e:
        return {'Error': f'An unexpected error occurred: {str(e)}'}

# %%
recommend_movies('dil dhadakne do',10)
# Out:
# Best Match is: dil dhadakne do
# [{'Title': "Isn't It Romantic",
#   'Top Cast': 'Rebel Wilson, Liam Hemsworth, Adam Devine, Priyanka Chopra Jonas, Betty Gilpin',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/yuyRg1WaY616Uux3vP9ONsUjQTS.jpg, https://image.tmdb.org/t/p/w200/7UIm9RoBnlqS1uLlbElAY8urdWD.jpg, https://image.tmdb.org/t/p/w200/8zU8zMs7cpjVzkBXis6I3wO3YeQ.jpg, https://image.tmdb.org/t/p/w200/stEZxIVAWFlrifbWkeULsD4LHnf.jpg, https://image.tmdb.org/t/p/w200/hBOviIHCVqbWyyPUoIxZohDl5SL.jpg',
#   'Description': 'For a long time, Natalie, an Australian architect living in New York City, had always believed that what she had seen in rom-coms is all fantasy. But after thwarting a mugger at a subway station only to be knocked out while fleeing, Natalie wakes up and discovers that her life has suddenly become her worst nightmare—a romantic comedy—and she is the leading lady.',
#   'Genre': 'Comedy, Fantasy, Romance',
#   'Language': 'English',
#   'Release Date': '13 Feb 2019',
#   'Rating': 6.211,
#   'Poster': 'https://image.tmdb.org/t/p/original/5xNBYXuv8wqiLVDhsfqCOr75DL7.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/449563-isn-t-it-romantic/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=8ZwgoVmILQU'},
#  {'Title': 'Heads of State',
#   'Top Cast': 'John Cena, Idris Elba, Priyanka Chopra Jonas, Jack Quaid, Carla Gugino',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/rgB2eIOt7WyQjdgJCOuESdDlrjg.jpg, https://image.tmdb.org/t/p/w200/be1bVF7qGX91a6c5WeRPs5pKXln.jpg, https://image.tmdb.org/t/p/w200/stEZxIVAWFlrifbWkeULsD4LHnf.jpg, https://image.tmdb.org/t/p/w200/320qW5yEbxpmyxQ3evmClJbtKag.jpg, https://image.tmdb.org/t/p/w200/7lSH5LOexOHwvt9lOTsLTbXdU1G.jpg',
#   'Description': "The UK Prime Minister and US President have a public rivalry that risks their countries’'alliance. But when they become targets of a powerful enemy, they're forced to rely on each other as they go on a wild, multinational run. Allied with Noel, a brilliant MI6 agent, they must find a way to thwart a conspiracy that threatens the free world.",
#   'Genre': 'Action, Thriller, Comedy',
#   'Language': 'English',
#   'Release Date': '01 Jul 2025',
#   'Rating': 0.0,
#   'Poster': 'https://image.tmdb.org/t/p/original/lVgE5oLzf7ABmzyASEVcjYyHI41.jpg',
#   'Stream': 'https://www.themoviedb.org/',
#   'Trailer': 'https://www.youtube.com/watch?v=8J646zM7UM8'},
#  {'Title': 'Sanju',
#   'Top Cast': 'Ranbir Kapoor, Paresh Rawal, Vicky Kaushal, Anushka Sharma, Dia Mirza',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/ymYNHV9luwgyrw17NXHqbOWTQkg.jpg, https://image.tmdb.org/t/p/w200/haRliZNMm04QXItBGScbFh4bHSJ.jpg, https://image.tmdb.org/t/p/w200/hKSa4DWEAD7DYhABYGwjPmxdpAY.jpg, https://image.tmdb.org/t/p/w200/8Xmfnwe6pf58duYqxxYv81phs2.jpg, https://image.tmdb.org/t/p/w200/oJSZlMkIGC1Yr8QxdBLliUjPRSd.jpg',
#   'Description': 'Sanju explores some of the most crucial chapters from movie star Sanjay Dutt’s dramatic and controversial real life. It gives a lowdown on his tryst with drugs and his trials and tribulations in the Arms Acts case and the 1993 Mumbai blasts.',
#   'Genre': 'Drama, Comedy',
#   'Language': 'Hindi',
#   'Release Date': '29 Jun 2018',
#   'Rating': 7.2,
#   'Poster': 'https://image.tmdb.org/t/p/original/q1wkN4VQuBTj1AeyTLLz2w6awMA.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/496328/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=1J76wN0TPI4'},
#  {'Title': 'Animal',
#   'Top Cast': 'Ranbir Kapoor, Rashmika Mandanna, Anil Kapoor, Bobby Deol, Triptii Dimri',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/ymYNHV9luwgyrw17NXHqbOWTQkg.jpg, https://image.tmdb.org/t/p/w200/fMotpuQYUfyPPWeRJk8C8ADBZrY.jpg, https://image.tmdb.org/t/p/w200/6RcrXGFzO50Tazqc8tbDlzYKvTd.jpg, https://image.tmdb.org/t/p/w200/2npVa3PduichY8e7qBiE54m9VVP.jpg, https://image.tmdb.org/t/p/w200/bAwn2jF0X67qUzmO27X34THLJ4w.jpg',
#   'Description': "The hardened son of a powerful industrialist returns home after years abroad and vows to take bloody revenge on those threatening his father's life.",
#   'Genre': 'Action, Crime, Drama',
#   'Language': 'Hindi',
#   'Release Date': '01 Dec 2023',
#   'Rating': 6.275,
#   'Poster': 'https://image.tmdb.org/t/p/original/hr9rjR3J0xBBKmlJ4n3gHId9ccx.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/781732-animal/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=6DfaBq2rVoE'},
#  {'Title': 'Baywatch',
#   'Top Cast': 'Dwayne Johnson, Zac Efron, Priyanka Chopra Jonas, Alexandra Daddario, Kelly Rohrbach',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/5QApZVV8FUFlVxQpIK3Ew6cqotq.jpg, https://image.tmdb.org/t/p/w200/pdWXP7XG6qqOoxoLid1DWYwmaMY.jpg, https://image.tmdb.org/t/p/w200/stEZxIVAWFlrifbWkeULsD4LHnf.jpg, https://image.tmdb.org/t/p/w200/lh5zibQXYH1MNqkuX8TmxyNYHhK.jpg, https://image.tmdb.org/t/p/w200/jmp1SZ0H30atVZrrguBWRD3vjX3.jpg',
#   'Description': 'अपने समुद्र तट को बचाने के लिए, एलीट लाइफ़गार्ड मिच ब्युकैनन और एक भूतपूर्व ओलंपिक खिलाड़ी ऐसे आपराधिक षड्यंत्र का पता लगाते हैं जिससे खाड़ी के भविष्य को खतरा हो सकता है.',
#   'Genre': 'Comedy, Action, Crime',
#   'Language': 'English',
#   'Release Date': '25 May 2017',
#   'Rating': 6.092,
#   'Poster': 'https://image.tmdb.org/t/p/original/4MsNxTKqriUTyhaKJvJZAMIDkpk.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/339846-baywatch/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=eyKOgnaf0BU'},
#  {'Title': 'PK',
#   'Top Cast': 'Aamir Khan, Anushka Sharma, Saurabh Shukla, Boman Irani, Sushant Singh Rajput',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/bI3yxh4FzKL2hHYS4nbzcDMWtZs.jpg, https://image.tmdb.org/t/p/w200/8Xmfnwe6pf58duYqxxYv81phs2.jpg, https://image.tmdb.org/t/p/w200/uFGVBmRIHLAQkYYSI2lSXOxMi4f.jpg, https://image.tmdb.org/t/p/w200/5J7GiiNar9bg9rGYeA2L30JXE2W.jpg, https://image.tmdb.org/t/p/w200/edfa1O57XP0S7fNZiEg3chelR91.jpg',
#   'Description': "A stranger in the city asks questions no one has asked before. Known only by his initials, the man's innocent questions and childlike curiosity take him on a journey of love, laughter and letting go.",
#   'Genre': 'Comedy, Drama, Science Fiction',
#   'Language': 'Hindi',
#   'Release Date': '18 Dec 2014',
#   'Rating': 7.714,
#   'Poster': 'https://image.tmdb.org/t/p/original/z2x2Y4tncefsIU7h82gmUM5vnBJ.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/297222/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=Not Available'},
#  {'Title': 'The White Tiger',
#   'Top Cast': 'Adarsh Gourav, Rajkummar Rao, Priyanka Chopra Jonas, Mahesh Manjrekar, Vijay Maurya',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/kuJ2ukWmuHnCSTOOvUMqiES5G2C.jpg, https://image.tmdb.org/t/p/w200/bCbQkvfnncgsh9qZ9u02IGtsfma.jpg, https://image.tmdb.org/t/p/w200/stEZxIVAWFlrifbWkeULsD4LHnf.jpg, https://image.tmdb.org/t/p/w200/rAAlncxpCKpXjUHsd6pfaSaTl96.jpg, https://image.tmdb.org/t/p/w200/bv5PBdLWy6MZxpDukrkHbaiLcsL.jpg',
#   'Description': 'An ambitious Indian driver uses his wit and cunning to escape from poverty and rise to the top. An epic journey based on the New York Times bestseller.',
#   'Genre': 'Drama',
#   'Language': 'English',
#   'Release Date': '13 Jan 2021',
#   'Rating': 6.97,
#   'Poster': 'https://image.tmdb.org/t/p/original/5JnmseS3DZ6ad2VMbrnbGCs8Rst.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/628534-the-white-tiger/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=35jJNyFuYKQ'},
#  {'Title': 'Rocky Aur Rani Kii Prem Kahaani',
#   'Top Cast': 'Alia Bhatt, Ranveer Singh, Jaya Bachchan, Shabana Azmi, Dharmendra',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/RBnTJPegPFLBS4VPsNLbf6iAoD.jpg, https://image.tmdb.org/t/p/w200/sRiwLmhduFghJo8U2coUafnDD4C.jpg, https://image.tmdb.org/t/p/w200/8A1BAAUSqNHeClIBIb02MBo0sBS.jpg, https://image.tmdb.org/t/p/w200/vAoYSYP4DFUMv7fZk9u8Bps9by.jpg, https://image.tmdb.org/t/p/w200/qRT0nOpxt14osa76nTrNduawX0l.jpg',
#   'Description': "Gym-freak brat Rocky falls in love with Rani, who comes from a well-educated Bengali family. Being from polar opposite worlds, the two decide to switch their families to adjust to each other's cultures and backgrounds and to know if their marriage will survive. Rocky and Rani are trapped in a world where they are united by love but divided by families and the ultimate question is will they fit in?",
#   'Genre': 'Comedy, Drama, Family, Romance',
#   'Language': 'Hindi',
#   'Release Date': '28 Jul 2023',
#   'Rating': 6.3,
#   'Poster': 'https://image.tmdb.org/t/p/original/vTQIqlxUkOuyf2UKhlM2OUaFGKz.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/848116/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=OWC6OErVtW8'},
#  {'Title': 'Padmaavat',
#   'Top Cast': 'Deepika Padukone, Ranveer Singh, Shahid Kapoor, Jim Sarbh, Aayam Mehta',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/sXgEh0z6NzyvmEeBeLPK1ON7NBY.jpg, https://image.tmdb.org/t/p/w200/sRiwLmhduFghJo8U2coUafnDD4C.jpg, https://image.tmdb.org/t/p/w200/q5jqLRioZgIVjXpKS8XHx27ScDQ.jpg, https://image.tmdb.org/t/p/w200/lJPX2ehRqqtrJOqx5PS9dkSAw7.jpg, https://image.tmdb.org/t/p/w200/qEBejJquDOqnDQbPmUYG7jZwN3J.jpg',
#   'Description': 'Rajputana, India, 13th century. The tyrannical usurper Alauddin Khilji, sultan of Delhi, becomes obsessed with Queen Padmavati, wife of King Ratan Singh of Mewar, and goes to great lengths to satisfy his greed for her.',
#   'Genre': 'Drama, History, Romance',
#   'Language': 'Hindi',
#   'Release Date': '25 Jan 2018',
#   'Rating': 6.9,
#   'Poster': 'https://image.tmdb.org/t/p/original/5kk71s8Vmvt8XQOojevhTA5QcB0.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/432527/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=X_5_BLt76c0'},
#  {'Title': 'Singham Again',
#   'Top Cast': 'Ajay Devgn, Akshay Kumar, Ranveer Singh, Tiger Shroff, Kareena Kapoor Khan',
#   'Cast Picture': 'https://image.tmdb.org/t/p/w200/83jDgHAPf4hPCFoF1OTF08xkhd6.jpg, https://image.tmdb.org/t/p/w200/1d77rFiN8h2JXE6vS8VCuc2k20J.jpg, https://image.tmdb.org/t/p/w200/sRiwLmhduFghJo8U2coUafnDD4C.jpg, https://image.tmdb.org/t/p/w200/kgvll1RBCcDTs6KJZFDb291AuZb.jpg, https://image.tmdb.org/t/p/w200/pJZJJ93NwJq3kb3RWtaZBYVga1x.jpg',
#   'Description': "The cop universe expands with newer additions while the old ones return led by Bajirao Singham. Singham Again interweaves the mythological epic Ramayana's good vs evil narrative when his wife Avni Kamath gets abducted by Danger Lanka setting Bajirao and his gang of Sangram Bhalerao and Veer Sooryavanshi along with Satya and Shakti Shetty on a mission to rescue her.",
#   'Genre': 'Action, Drama, Thriller, Crime',
#   'Language': 'Hindi',
#   'Release Date': '01 Nov 2024',
#   'Rating': 4.3,
#   'Poster': 'https://image.tmdb.org/t/p/original/2JbNkHg8m7LaBy61LyrnnlenaxY.jpg',
#   'Stream': 'https://www.themoviedb.org/movie/1014214/watch?locale=IN',
#   'Trailer': 'https://www.youtube.com/watch?v=DovbhJavvfU'}]
